# %%
import os
import numpy as np
from pathlib import Path
import json
import collections
import torch
import torch.utils.data
from PIL import Image

# %%
class KCocoDataset(torch.utils.data.Dataset):
    def __init__(self, root, jsonname, transforms = None):
        self.root = root
        self.PATH = Path(root)        
        self.jsonname = jsonname
        self.transforms =  transforms                
        
        trn_j = json.load( (self.PATH/jsonname).open() )        
        self.images = trn_j['images']
        #self.annotations = trn_j['annotations']
        self.cats =  {o['id']:o['name'] for o in trn_j['categories']}
        self.trn_fns = {o['id']:o['file_name'] for o in trn_j['images']}
        self.trn_ids = [o['id'] for o in trn_j['images']]        
        
        self.trn_anno = collections.defaultdict( lambda:[] )
        for o in trn_j['annotations']:
            if not o['ignore']:
                bb = o['bbox']
                #bb = hw_bb(bb)
                self.trn_anno[o['image_id']].append((bb, o['category_id'], o['area'], o['iscrowd']))        
    
    def __getitem__(self, idx):
        img_id = self.trn_ids[idx]
        img_name = self.trn_fns[img_id]
        #print("img_id", img_id)
        #print("img_name", img_name)
        JPEGS = 'VOCdevkit/VOC2007/JPEGImages'
        img = Image.open( self.PATH/JPEGS/img_name ).convert("RGB")

        boxes = []
        labels = []
        areas = []
        iscrowds = []
        for o in self.trn_anno[img_id]:
            #print("o", o)
            x = o[0][0]
            y = o[0][1]
            width = o[0][2]
            height = o[0][3]            
            boxes.append( [x, y, x + width -1, y + height -1] )
            
            labels.append(o[1])
            areas.append(o[2])
            iscrowds.append(o[3])
            
        target = {}                
        
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        areas = torch.as_tensor(areas, dtype=torch.float32)
        iscrowds = torch.as_tensor(iscrowds, dtype=torch.int64)
        
        image_id = torch.tensor([img_id])        
        
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = areas
        target["iscrowd"] = iscrowds       
        
        
        if self.transforms is not None:
            img, target = self.transforms(img, target)
        return img, target
    
    def __len__(self):
        return len( self.images)

# %%
class PennFudanDataset(object):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))

    def __getitem__(self, idx):
        # load images ad masks
        img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])
        img = Image.open(img_path).convert("RGB")
        # note that we haven't converted the mask to RGB,
        # because each color corresponds to a different instance
        # with 0 being background
        mask = Image.open(mask_path)
        # convert the PIL Image into a numpy array
        mask = np.array(mask)
        
        # instances are encoded as different colors
        obj_ids = np.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]        
        

        # split the color-encoded mask into a set
        # of binary masks
        masks = mask == obj_ids[:, None, None]

        # get bounding box coordinates for each mask
        num_objs = len(obj_ids)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])
            #print("xmin={}, ymin={}, xmax={}, ymax={}".format(xmin, ymin, xmax, ymax) )
            

        # convert everything into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)
        #masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        #target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        
#         print("type(boxes)", type(boxes), boxes.shape)
#         print("type(labels)", type(labels), labels.shape)
#         print("type(image_id)", type(image_id), image_id.shape)
#         print("type(area)", type(area), area.shape)
#         print("type(iscrowd)", type(iscrowd), iscrowd.shape)
        

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor


def get_model_instance_segmentation(num_classes, pretrain):
    # load an instance segmentation model pre-trained pre-trained on COCO    
    #model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)    
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=pretrain)    

    
    in_features = model.roi_heads.box_predictor.cls_score.in_features    
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model

# %%
from engine import train_one_epoch, evaluate
import utils
import transforms as T


def get_transform(train):
    transforms = []    
    transforms.append(T.ToTensor())
    if train:
        # during training, randomly flip the training images
        # and ground-truth for data augmentation
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# %%
from engine import train_one_epoch, evaluate
import utils

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("device", device)

# our dataset has two classes only - background and person
num_classes = 20 + 1

# use our dataset and defined transformations
#dataset = PennFudanDataset('PennFudanPed', get_transform(train=True))
#dataset_test = PennFudanDataset('PennFudanPed', get_transform(train=False))

dataset = KCocoDataset('data/pascal', 'pascal_train2007.json', get_transform(train=True))
dataset_test = KCocoDataset('data/pascal', 'pascal_train2007.json', get_transform(train=False))

# split the dataset in train and test set
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:-50])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])


# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=2, shuffle=True, num_workers=0,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=0,
    collate_fn=utils.collate_fn)

# get the model using our helper function
model = get_model_instance_segmentation(num_classes, True)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# let's train it for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)    
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

SAVED_PATH = './voc20_epoch10_2019.06.26.nn.pt'
# save the target path.
torch.save(model.state_dict(), SAVED_PATH)
print("model saved.")
# Out:
# device cuda
# Epoch: [0]  [   0/1226]  eta: 0:37:23  lr: 0.000010  loss: 3.4188 (3.4188)  loss_classifier: 3.1926 (3.1926)  loss_box_reg: 0.1686 (0.1686)  loss_objectness: 0.0358 (0.0358)  loss_rpn_box_reg: 0.0219 (0.0219)  time: 1.8296  data: 0.0401  max mem: 3550
# Epoch: [0]  [  10/1226]  eta: 0:10:58  lr: 0.000060  loss: 3.3425 (3.3544)  loss_classifier: 3.0749 (3.0942)  loss_box_reg: 0.1784 (0.2196)  loss_objectness: 0.0178 (0.0213)  loss_rpn_box_reg: 0.0169 (0.0194)  time: 0.5419  data: 0.0189  max mem: 5217
# Epoch: [0]  [  20/1226]  eta: 0:09:38  lr: 0.000110  loss: 3.1673 (2.9508)  loss_classifier: 2.8418 (2.6819)  loss_box_reg: 0.2127 (0.2352)  loss_objectness: 0.0058 (0.0161)  loss_rpn_box_reg: 0.0168 (0.0176)  time: 0.4119  data: 0.0155  max mem: 5482
# Epoch: [0]  [  30/1226]  eta: 0:09:00  lr: 0.000160  loss: 1.7455 (2.3747)  loss_classifier: 1.3513 (2.1082)  loss_box_reg: 0.2526 (0.2346)  loss_objectness: 0.0111 (0.0149)  loss_rpn_box_reg: 0.0133 (0.0171)  time: 0.4018  data: 0.0149  max mem: 5642
# Epoch: [0]  [  40/1226]  eta: 0:08:33  lr: 0.000210  loss: 0.9322 (1.9610)  loss_classifier: 0.6483 (1.7008)  loss_box_reg: 0.1943 (0.2289)  loss_objectness: 0.0078 (0.0127)  loss_rpn_box_reg: 0.0133 (0.0185)  time: 0.3851  data: 0.0160  max mem: 5642
# Epoch: [0]  [  50/1226]  eta: 0:08:18  lr: 0.000260  loss: 0.5885 (1.7282)  loss_classifier: 0.4012 (1.4658)  loss_box_reg: 0.1827 (0.2323)  loss_objectness: 0.0045 (0.0118)  loss_rpn_box_reg: 0.0144 (0.0184)  time: 0.3807  data: 0.0151  max mem: 5642
# Epoch: [0]  [  60/1226]  eta: 0:08:06  lr: 0.000310  loss: 0.7841 (1.5753)  loss_classifier: 0.5114 (1.3086)  loss_box_reg: 0.2270 (0.2348)  loss_objectness: 0.0086 (0.0117)  loss_rpn_box_reg: 0.0175 (0.0200)  time: 0.3831  data: 0.0149  max mem: 5642
# Epoch: [0]  [  70/1226]  eta: 0:08:00  lr: 0.000360  loss: 0.6835 (1.4533)  loss_classifier: 0.4168 (1.1855)  loss_box_reg: 0.2188 (0.2368)  loss_objectness: 0.0080 (0.0109)  loss_rpn_box_reg: 0.0122 (0.0200)  time: 0.3959  data: 0.0151  max mem: 5642
# Epoch: [0]  [  80/1226]  eta: 0:07:55  lr: 0.000410  loss: 0.5302 (1.3485)  loss_classifier: 0.3519 (1.0849)  loss_box_reg: 0.1848 (0.2327)  loss_objectness: 0.0043 (0.0108)  loss_rpn_box_reg: 0.0120 (0.0201)  time: 0.4101  data: 0.0156  max mem: 5642
# Epoch: [0]  [  90/1226]  eta: 0:07:48  lr: 0.000460  loss: 0.4807 (1.2685)  loss_classifier: 0.2866 (1.0073)  loss_box_reg: 0.1652 (0.2301)  loss_objectness: 0.0046 (0.0112)  loss_rpn_box_reg: 0.0139 (0.0199)  time: 0.3997  data: 0.0166  max mem: 5642
# Epoch: [0]  [ 100/1226]  eta: 0:07:40  lr: 0.000509  loss: 0.5989 (1.2096)  loss_classifier: 0.3523 (0.9476)  loss_box_reg: 0.2165 (0.2306)  loss_objectness: 0.0077 (0.0109)  loss_rpn_box_reg: 0.0203 (0.0205)  time: 0.3820  data: 0.0162  max mem: 5642
# Epoch: [0]  [ 110/1226]  eta: 0:07:32  lr: 0.000559  loss: 0.5989 (1.1574)  loss_classifier: 0.3523 (0.8957)  loss_box_reg: 0.2213 (0.2307)  loss_objectness: 0.0078 (0.0109)  loss_rpn_box_reg: 0.0165 (0.0202)  time: 0.3761  data: 0.0158  max mem: 5642
# Epoch: [0]  [ 120/1226]  eta: 0:07:26  lr: 0.000609  loss: 0.7138 (1.1178)  loss_classifier: 0.4036 (0.8554)  loss_box_reg: 0.2389 (0.2321)  loss_objectness: 0.0030 (0.0107)  loss_rpn_box_reg: 0.0136 (0.0196)  time: 0.3799  data: 0.0150  max mem: 5642
# Epoch: [0]  [ 130/1226]  eta: 0:07:24  lr: 0.000659  loss: 0.4543 (1.0619)  loss_classifier: 0.2757 (0.8067)  loss_box_reg: 0.1461 (0.2244)  loss_objectness: 0.0040 (0.0106)  loss_rpn_box_reg: 0.0161 (0.0202)  time: 0.4048  data: 0.0151  max mem: 5771
# Epoch: [0]  [ 140/1226]  eta: 0:07:20  lr: 0.000709  loss: 0.3252 (1.0210)  loss_classifier: 0.1799 (0.7691)  loss_box_reg: 0.1072 (0.2208)  loss_objectness: 0.0040 (0.0102)  loss_rpn_box_reg: 0.0217 (0.0208)  time: 0.4139  data: 0.0149  max mem: 5771
# Epoch: [0]  [ 150/1226]  eta: 0:07:15  lr: 0.000759  loss: 0.3836 (0.9839)  loss_classifier: 0.2033 (0.7345)  loss_box_reg: 0.1395 (0.2176)  loss_objectness: 0.0036 (0.0106)  loss_rpn_box_reg: 0.0190 (0.0212)  time: 0.3959  data: 0.0145  max mem: 5771
# Epoch: [0]  [ 160/1226]  eta: 0:07:10  lr: 0.000809  loss: 0.4713 (0.9663)  loss_classifier: 0.2723 (0.7147)  loss_box_reg: 0.1740 (0.2201)  loss_objectness: 0.0079 (0.0105)  loss_rpn_box_reg: 0.0185 (0.0210)  time: 0.3935  data: 0.0149  max mem: 5771
# Epoch: [0]  [ 170/1226]  eta: 0:07:05  lr: 0.000859  loss: 0.4685 (0.9331)  loss_classifier: 0.2705 (0.6854)  loss_box_reg: 0.1695 (0.2161)  loss_objectness: 0.0079 (0.0108)  loss_rpn_box_reg: 0.0171 (0.0208)  time: 0.3947  data: 0.0153  max mem: 5771
# Epoch: [0]  [ 180/1226]  eta: 0:07:01  lr: 0.000909  loss: 0.4228 (0.9060)  loss_classifier: 0.2409 (0.6610)  loss_box_reg: 0.1614 (0.2140)  loss_objectness: 0.0043 (0.0104)  loss_rpn_box_reg: 0.0129 (0.0206)  time: 0.3958  data: 0.0149  max mem: 5771
# Epoch: [0]  [ 190/1226]  eta: 0:06:56  lr: 0.000959  loss: 0.4476 (0.8828)  loss_classifier: 0.2409 (0.6389)  loss_box_reg: 0.1738 (0.2128)  loss_objectness: 0.0027 (0.0104)  loss_rpn_box_reg: 0.0129 (0.0207)  time: 0.3938  data: 0.0151  max mem: 5771
# Epoch: [0]  [ 200/1226]  eta: 0:06:51  lr: 0.001009  loss: 0.4158 (0.8622)  loss_classifier: 0.2261 (0.6198)  loss_box_reg: 0.1669 (0.2117)  loss_objectness: 0.0051 (0.0101)  loss_rpn_box_reg: 0.0144 (0.0205)  time: 0.3849  data: 0.0153  max mem: 5771
# Epoch: [0]  [ 210/1226]  eta: 0:06:47  lr: 0.001059  loss: 0.3038 (0.8407)  loss_classifier: 0.1679 (0.6006)  loss_box_reg: 0.1242 (0.2091)  loss_objectness: 0.0025 (0.0101)  loss_rpn_box_reg: 0.0144 (0.0209)  time: 0.3929  data: 0.0156  max mem: 5771
# Epoch: [0]  [ 220/1226]  eta: 0:06:42  lr: 0.001109  loss: 0.3562 (0.8231)  loss_classifier: 0.2074 (0.5837)  loss_box_reg: 0.1398 (0.2084)  loss_objectness: 0.0019 (0.0102)  loss_rpn_box_reg: 0.0169 (0.0208)  time: 0.3938  data: 0.0157  max mem: 5771
# Epoch: [0]  [ 230/1226]  eta: 0:06:37  lr: 0.001159  loss: 0.4921 (0.8189)  loss_classifier: 0.2713 (0.5761)  loss_box_reg: 0.1787 (0.2110)  loss_objectness: 0.0048 (0.0104)  loss_rpn_box_reg: 0.0182 (0.0215)  time: 0.3811  data: 0.0143  max mem: 5771
# Epoch: [0]  [ 240/1226]  eta: 0:06:33  lr: 0.001209  loss: 0.5553 (0.8040)  loss_classifier: 0.2995 (0.5625)  loss_box_reg: 0.1950 (0.2089)  loss_objectness: 0.0050 (0.0103)  loss_rpn_box_reg: 0.0189 (0.0224)  time: 0.3877  data: 0.0142  max mem: 5771
# Epoch: [0]  [ 250/1226]  eta: 0:06:28  lr: 0.001259  loss: 0.4161 (0.7943)  loss_classifier: 0.2023 (0.5530)  loss_box_reg: 0.1692 (0.2088)  loss_objectness: 0.0026 (0.0102)  loss_rpn_box_reg: 0.0172 (0.0223)  time: 0.3818  data: 0.0151  max mem: 5771
# Epoch: [0]  [ 260/1226]  eta: 0:06:24  lr: 0.001309  loss: 0.4694 (0.7826)  loss_classifier: 0.2023 (0.5413)  loss_box_reg: 0.2006 (0.2085)  loss_objectness: 0.0035 (0.0102)  loss_rpn_box_reg: 0.0171 (0.0226)  time: 0.3756  data: 0.0155  max mem: 5771
# Epoch: [0]  [ 270/1226]  eta: 0:06:20  lr: 0.001359  loss: 0.3564 (0.7658)  loss_classifier: 0.1812 (0.5273)  loss_box_reg: 0.1348 (0.2057)  loss_objectness: 0.0061 (0.0100)  loss_rpn_box_reg: 0.0155 (0.0229)  time: 0.3928  data: 0.0156  max mem: 5771
# Epoch: [0]  [ 280/1226]  eta: 0:06:16  lr: 0.001409  loss: 0.3472 (0.7498)  loss_classifier: 0.1635 (0.5138)  loss_box_reg: 0.1231 (0.2028)  loss_objectness: 0.0042 (0.0099)  loss_rpn_box_reg: 0.0221 (0.0233)  time: 0.4010  data: 0.0154  max mem: 5771
# Epoch: [0]  [ 290/1226]  eta: 0:06:11  lr: 0.001459  loss: 0.3035 (0.7341)  loss_classifier: 0.1532 (0.5010)  loss_box_reg: 0.1386 (0.2003)  loss_objectness: 0.0042 (0.0097)  loss_rpn_box_reg: 0.0209 (0.0230)  time: 0.3898  data: 0.0149  max mem: 5771
# Epoch: [0]  [ 300/1226]  eta: 0:06:07  lr: 0.001508  loss: 0.3035 (0.7225)  loss_classifier: 0.1521 (0.4909)  loss_box_reg: 0.1386 (0.1987)  loss_objectness: 0.0048 (0.0097)  loss_rpn_box_reg: 0.0135 (0.0232)  time: 0.3808  data: 0.0151  max mem: 5771
# Epoch: [0]  [ 310/1226]  eta: 0:06:03  lr: 0.001558  loss: 0.2644 (0.7088)  loss_classifier: 0.1383 (0.4793)  loss_box_reg: 0.1286 (0.1967)  loss_objectness: 0.0018 (0.0094)  loss_rpn_box_reg: 0.0176 (0.0234)  time: 0.3902  data: 0.0158  max mem: 5771
# Epoch: [0]  [ 320/1226]  eta: 0:06:00  lr: 0.001608  loss: 0.2612 (0.6975)  loss_classifier: 0.1197 (0.4694)  loss_box_reg: 0.1286 (0.1951)  loss_objectness: 0.0014 (0.0094)  loss_rpn_box_reg: 0.0204 (0.0235)  time: 0.4137  data: 0.0160  max mem: 5771
# Epoch: [0]  [ 330/1226]  eta: 0:05:56  lr: 0.001658  loss: 0.2345 (0.6831)  loss_classifier: 0.1078 (0.4582)  loss_box_reg: 0.0986 (0.1919)  loss_objectness: 0.0024 (0.0093)  loss_rpn_box_reg: 0.0225 (0.0237)  time: 0.4114  data: 0.0147  max mem: 5771
# Epoch: [0]  [ 340/1226]  eta: 0:05:52  lr: 0.001708  loss: 0.2383 (0.6743)  loss_classifier: 0.1078 (0.4499)  loss_box_reg: 0.0986 (0.1910)  loss_objectness: 0.0024 (0.0095)  loss_rpn_box_reg: 0.0256 (0.0238)  time: 0.3913  data: 0.0151  max mem: 5771
# Epoch: [0]  [ 350/1226]  eta: 0:05:47  lr: 0.001758  loss: 0.3638 (0.6685)  loss_classifier: 0.1571 (0.4443)  loss_box_reg: 0.1397 (0.1905)  loss_objectness: 0.0032 (0.0097)  loss_rpn_box_reg: 0.0272 (0.0241)  time: 0.3901  data: 0.0167  max mem: 5771
# Epoch: [0]  [ 360/1226]  eta: 0:05:43  lr: 0.001808  loss: 0.3389 (0.6587)  loss_classifier: 0.1749 (0.4361)  loss_box_reg: 0.1397 (0.1893)  loss_objectness: 0.0082 (0.0096)  loss_rpn_box_reg: 0.0130 (0.0237)  time: 0.3850  data: 0.0159  max mem: 5771
# Epoch: [0]  [ 370/1226]  eta: 0:05:39  lr: 0.001858  loss: 0.2807 (0.6502)  loss_classifier: 0.1647 (0.4290)  loss_box_reg: 0.1229 (0.1879)  loss_objectness: 0.0042 (0.0095)  loss_rpn_box_reg: 0.0140 (0.0237)  time: 0.3900  data: 0.0146  max mem: 5771
# Epoch: [0]  [ 380/1226]  eta: 0:05:35  lr: 0.001908  loss: 0.2807 (0.6408)  loss_classifier: 0.1297 (0.4216)  loss_box_reg: 0.1086 (0.1863)  loss_objectness: 0.0031 (0.0094)  loss_rpn_box_reg: 0.0176 (0.0236)  time: 0.4001  data: 0.0138  max mem: 5771
# Epoch: [0]  [ 390/1226]  eta: 0:05:31  lr: 0.001958  loss: 0.1914 (0.6293)  loss_classifier: 0.0883 (0.4130)  loss_box_reg: 0.0842 (0.1835)  loss_objectness: 0.0022 (0.0093)  loss_rpn_box_reg: 0.0162 (0.0235)  time: 0.3799  data: 0.0131  max mem: 5771
# Epoch: [0]  [ 400/1226]  eta: 0:05:26  lr: 0.002008  loss: 0.2217 (0.6222)  loss_classifier: 0.0895 (0.4066)  loss_box_reg: 0.1141 (0.1829)  loss_objectness: 0.0022 (0.0092)  loss_rpn_box_reg: 0.0162 (0.0234)  time: 0.3728  data: 0.0128  max mem: 5771
# Epoch: [0]  [ 410/1226]  eta: 0:05:22  lr: 0.002058  loss: 0.2928 (0.6146)  loss_classifier: 0.1342 (0.4004)  loss_box_reg: 0.1230 (0.1817)  loss_objectness: 0.0023 (0.0092)  loss_rpn_box_reg: 0.0151 (0.0233)  time: 0.3766  data: 0.0137  max mem: 5771
# Epoch: [0]  [ 420/1226]  eta: 0:05:18  lr: 0.002108  loss: 0.2887 (0.6066)  loss_classifier: 0.1342 (0.3937)  loss_box_reg: 0.1118 (0.1805)  loss_objectness: 0.0030 (0.0091)  loss_rpn_box_reg: 0.0134 (0.0233)  time: 0.3731  data: 0.0157  max mem: 5771
# Epoch: [0]  [ 430/1226]  eta: 0:05:13  lr: 0.002158  loss: 0.2887 (0.6014)  loss_classifier: 0.1406 (0.3887)  loss_box_reg: 0.1250 (0.1803)  loss_objectness: 0.0031 (0.0090)  loss_rpn_box_reg: 0.0140 (0.0233)  time: 0.3812  data: 0.0167  max mem: 5771
# Epoch: [0]  [ 440/1226]  eta: 0:05:09  lr: 0.002208  loss: 0.3038 (0.5947)  loss_classifier: 0.1325 (0.3833)  loss_box_reg: 0.1387 (0.1792)  loss_objectness: 0.0035 (0.0090)  loss_rpn_box_reg: 0.0170 (0.0232)  time: 0.3787  data: 0.0168  max mem: 5771
# Epoch: [0]  [ 450/1226]  eta: 0:05:05  lr: 0.002258  loss: 0.2173 (0.5876)  loss_classifier: 0.1166 (0.3780)  loss_box_reg: 0.0859 (0.1772)  loss_objectness: 0.0023 (0.0093)  loss_rpn_box_reg: 0.0135 (0.0232)  time: 0.3785  data: 0.0147  max mem: 5771
# Epoch: [0]  [ 460/1226]  eta: 0:05:01  lr: 0.002308  loss: 0.2111 (0.5811)  loss_classifier: 0.1177 (0.3728)  loss_box_reg: 0.0791 (0.1758)  loss_objectness: 0.0026 (0.0093)  loss_rpn_box_reg: 0.0172 (0.0232)  time: 0.3939  data: 0.0144  max mem: 5771
# Epoch: [0]  [ 470/1226]  eta: 0:04:57  lr: 0.002358  loss: 0.2805 (0.5746)  loss_classifier: 0.1322 (0.3676)  loss_box_reg: 0.1089 (0.1746)  loss_objectness: 0.0026 (0.0091)  loss_rpn_box_reg: 0.0180 (0.0233)  time: 0.3984  data: 0.0160  max mem: 5771
# Epoch: [0]  [ 480/1226]  eta: 0:04:53  lr: 0.002408  loss: 0.3059 (0.5708)  loss_classifier: 0.1334 (0.3635)  loss_box_reg: 0.1389 (0.1748)  loss_objectness: 0.0021 (0.0091)  loss_rpn_box_reg: 0.0184 (0.0235)  time: 0.3759  data: 0.0148  max mem: 5771
# Epoch: [0]  [ 490/1226]  eta: 0:04:49  lr: 0.002458  loss: 0.3416 (0.5656)  loss_classifier: 0.1651 (0.3593)  loss_box_reg: 0.1593 (0.1738)  loss_objectness: 0.0082 (0.0092)  loss_rpn_box_reg: 0.0187 (0.0234)  time: 0.3745  data: 0.0142  max mem: 5771
# Epoch: [0]  [ 500/1226]  eta: 0:04:45  lr: 0.002507  loss: 0.2976 (0.5623)  loss_classifier: 0.1356 (0.3560)  loss_box_reg: 0.1326 (0.1737)  loss_objectness: 0.0082 (0.0092)  loss_rpn_box_reg: 0.0193 (0.0234)  time: 0.3806  data: 0.0156  max mem: 5771
# Epoch: [0]  [ 510/1226]  eta: 0:04:41  lr: 0.002557  loss: 0.2877 (0.5561)  loss_classifier: 0.1348 (0.3518)  loss_box_reg: 0.1183 (0.1719)  loss_objectness: 0.0058 (0.0091)  loss_rpn_box_reg: 0.0189 (0.0233)  time: 0.3883  data: 0.0153  max mem: 5771
# Epoch: [0]  [ 520/1226]  eta: 0:04:37  lr: 0.002607  loss: 0.2725 (0.5515)  loss_classifier: 0.1613 (0.3483)  loss_box_reg: 0.0904 (0.1708)  loss_objectness: 0.0058 (0.0091)  loss_rpn_box_reg: 0.0158 (0.0233)  time: 0.3863  data: 0.0151  max mem: 5771
# Epoch: [0]  [ 530/1226]  eta: 0:04:32  lr: 0.002657  loss: 0.3059 (0.5473)  loss_classifier: 0.1613 (0.3443)  loss_box_reg: 0.1107 (0.1706)  loss_objectness: 0.0054 (0.0091)  loss_rpn_box_reg: 0.0159 (0.0233)  time: 0.3719  data: 0.0148  max mem: 5771
# Epoch: [0]  [ 540/1226]  eta: 0:04:28  lr: 0.002707  loss: 0.2920 (0.5427)  loss_classifier: 0.1515 (0.3410)  loss_box_reg: 0.1187 (0.1693)  loss_objectness: 0.0030 (0.0092)  loss_rpn_box_reg: 0.0109 (0.0231)  time: 0.3792  data: 0.0153  max mem: 5771
# Epoch: [0]  [ 550/1226]  eta: 0:04:24  lr: 0.002757  loss: 0.2443 (0.5370)  loss_classifier: 0.1199 (0.3369)  loss_box_reg: 0.0784 (0.1678)  loss_objectness: 0.0032 (0.0092)  loss_rpn_box_reg: 0.0108 (0.0231)  time: 0.3791  data: 0.0159  max mem: 5771
# Epoch: [0]  [ 560/1226]  eta: 0:04:20  lr: 0.002807  loss: 0.2703 (0.5338)  loss_classifier: 0.1194 (0.3345)  loss_box_reg: 0.1116 (0.1671)  loss_objectness: 0.0037 (0.0091)  loss_rpn_box_reg: 0.0143 (0.0230)  time: 0.3850  data: 0.0146  max mem: 5771
# Epoch: [0]  [ 570/1226]  eta: 0:04:16  lr: 0.002857  loss: 0.2411 (0.5299)  loss_classifier: 0.1321 (0.3318)  loss_box_reg: 0.1148 (0.1660)  loss_objectness: 0.0038 (0.0093)  loss_rpn_box_reg: 0.0129 (0.0228)  time: 0.3918  data: 0.0158  max mem: 5771
# Epoch: [0]  [ 580/1226]  eta: 0:04:13  lr: 0.002907  loss: 0.2285 (0.5254)  loss_classifier: 0.1146 (0.3284)  loss_box_reg: 0.0760 (0.1649)  loss_objectness: 0.0052 (0.0092)  loss_rpn_box_reg: 0.0173 (0.0229)  time: 0.3939  data: 0.0179  max mem: 5771
# Epoch: [0]  [ 590/1226]  eta: 0:04:09  lr: 0.002957  loss: 0.2280 (0.5204)  loss_classifier: 0.1134 (0.3248)  loss_box_reg: 0.0770 (0.1636)  loss_objectness: 0.0016 (0.0091)  loss_rpn_box_reg: 0.0193 (0.0228)  time: 0.3947  data: 0.0167  max mem: 5771
# Epoch: [0]  [ 600/1226]  eta: 0:04:05  lr: 0.003007  loss: 0.2310 (0.5166)  loss_classifier: 0.1072 (0.3218)  loss_box_reg: 0.0784 (0.1628)  loss_objectness: 0.0017 (0.0092)  loss_rpn_box_reg: 0.0144 (0.0228)  time: 0.3880  data: 0.0152  max mem: 5771
# Epoch: [0]  [ 610/1226]  eta: 0:04:01  lr: 0.003057  loss: 0.2252 (0.5119)  loss_classifier: 0.1004 (0.3182)  loss_box_reg: 0.0977 (0.1617)  loss_objectness: 0.0017 (0.0092)  loss_rpn_box_reg: 0.0156 (0.0228)  time: 0.3814  data: 0.0146  max mem: 5771
# Epoch: [0]  [ 620/1226]  eta: 0:03:57  lr: 0.003107  loss: 0.2164 (0.5082)  loss_classifier: 0.1034 (0.3153)  loss_box_reg: 0.0853 (0.1609)  loss_objectness: 0.0050 (0.0092)  loss_rpn_box_reg: 0.0165 (0.0229)  time: 0.3894  data: 0.0149  max mem: 5771
# Epoch: [0]  [ 630/1226]  eta: 0:03:53  lr: 0.003157  loss: 0.2941 (0.5054)  loss_classifier: 0.1536 (0.3129)  loss_box_reg: 0.1262 (0.1604)  loss_objectness: 0.0058 (0.0092)  loss_rpn_box_reg: 0.0174 (0.0229)  time: 0.4008  data: 0.0163  max mem: 5771
# Epoch: [0]  [ 640/1226]  eta: 0:03:49  lr: 0.003207  loss: 0.3567 (0.5029)  loss_classifier: 0.1616 (0.3108)  loss_box_reg: 0.1358 (0.1598)  loss_objectness: 0.0081 (0.0093)  loss_rpn_box_reg: 0.0197 (0.0229)  time: 0.3970  data: 0.0159  max mem: 5771
# Epoch: [0]  [ 650/1226]  eta: 0:03:45  lr: 0.003257  loss: 0.2124 (0.4989)  loss_classifier: 0.1008 (0.3081)  loss_box_reg: 0.0792 (0.1587)  loss_objectness: 0.0047 (0.0092)  loss_rpn_box_reg: 0.0207 (0.0229)  time: 0.3866  data: 0.0162  max mem: 5771
# Epoch: [0]  [ 660/1226]  eta: 0:03:41  lr: 0.003307  loss: 0.2124 (0.4955)  loss_classifier: 0.1229 (0.3056)  loss_box_reg: 0.0792 (0.1580)  loss_objectness: 0.0027 (0.0091)  loss_rpn_box_reg: 0.0159 (0.0228)  time: 0.3881  data: 0.0186  max mem: 5771
# Epoch: [0]  [ 670/1226]  eta: 0:03:38  lr: 0.003357  loss: 0.3056 (0.4926)  loss_classifier: 0.1487 (0.3030)  loss_box_reg: 0.1116 (0.1576)  loss_objectness: 0.0027 (0.0092)  loss_rpn_box_reg: 0.0166 (0.0229)  time: 0.4120  data: 0.0172  max mem: 5771
# Epoch: [0]  [ 680/1226]  eta: 0:03:34  lr: 0.003407  loss: 0.2348 (0.4890)  loss_classifier: 0.0983 (0.3003)  loss_box_reg: 0.1116 (0.1568)  loss_objectness: 0.0053 (0.0091)  loss_rpn_box_reg: 0.0195 (0.0228)  time: 0.4069  data: 0.0135  max mem: 5771
# Epoch: [0]  [ 690/1226]  eta: 0:03:30  lr: 0.003457  loss: 0.2109 (0.4864)  loss_classifier: 0.1148 (0.2981)  loss_box_reg: 0.0974 (0.1564)  loss_objectness: 0.0025 (0.0091)  loss_rpn_box_reg: 0.0120 (0.0228)  time: 0.3869  data: 0.0139  max mem: 5771
# Epoch: [0]  [ 700/1226]  eta: 0:03:26  lr: 0.003506  loss: 0.2403 (0.4836)  loss_classifier: 0.1264 (0.2956)  loss_box_reg: 0.0974 (0.1557)  loss_objectness: 0.0037 (0.0093)  loss_rpn_box_reg: 0.0198 (0.0230)  time: 0.4057  data: 0.0159  max mem: 6375
# Epoch: [0]  [ 710/1226]  eta: 0:03:22  lr: 0.003556  loss: 0.2000 (0.4797)  loss_classifier: 0.1206 (0.2929)  loss_box_reg: 0.0596 (0.1545)  loss_objectness: 0.0070 (0.0093)  loss_rpn_box_reg: 0.0176 (0.0230)  time: 0.3939  data: 0.0161  max mem: 6375
# Epoch: [0]  [ 720/1226]  eta: 0:03:18  lr: 0.003606  loss: 0.2095 (0.4768)  loss_classifier: 0.1145 (0.2907)  loss_box_reg: 0.0553 (0.1536)  loss_objectness: 0.0067 (0.0093)  loss_rpn_box_reg: 0.0215 (0.0232)  time: 0.3839  data: 0.0153  max mem: 6375
# Epoch: [0]  [ 730/1226]  eta: 0:03:14  lr: 0.003656  loss: 0.2095 (0.4736)  loss_classifier: 0.1044 (0.2885)  loss_box_reg: 0.0705 (0.1528)  loss_objectness: 0.0038 (0.0093)  loss_rpn_box_reg: 0.0248 (0.0231)  time: 0.3911  data: 0.0139  max mem: 6375
# Epoch: [0]  [ 740/1226]  eta: 0:03:10  lr: 0.003706  loss: 0.1830 (0.4697)  loss_classifier: 0.0849 (0.2860)  loss_box_reg: 0.0632 (0.1515)  loss_objectness: 0.0030 (0.0092)  loss_rpn_box_reg: 0.0166 (0.0231)  time: 0.3785  data: 0.0149  max mem: 6375
# Epoch: [0]  [ 750/1226]  eta: 0:03:06  lr: 0.003756  loss: 0.2543 (0.4686)  loss_classifier: 0.1626 (0.2849)  loss_box_reg: 0.0718 (0.1512)  loss_objectness: 0.0057 (0.0094)  loss_rpn_box_reg: 0.0170 (0.0231)  time: 0.3754  data: 0.0158  max mem: 6375
# Epoch: [0]  [ 760/1226]  eta: 0:03:02  lr: 0.003806  loss: 0.3123 (0.4665)  loss_classifier: 0.1982 (0.2836)  loss_box_reg: 0.1065 (0.1506)  loss_objectness: 0.0070 (0.0093)  loss_rpn_box_reg: 0.0164 (0.0230)  time: 0.3813  data: 0.0144  max mem: 6375
# Epoch: [0]  [ 770/1226]  eta: 0:02:58  lr: 0.003856  loss: 0.2370 (0.4640)  loss_classifier: 0.1111 (0.2817)  loss_box_reg: 0.0817 (0.1500)  loss_objectness: 0.0040 (0.0093)  loss_rpn_box_reg: 0.0164 (0.0230)  time: 0.3931  data: 0.0161  max mem: 6375
# Epoch: [0]  [ 780/1226]  eta: 0:02:54  lr: 0.003906  loss: 0.2470 (0.4613)  loss_classifier: 0.1193 (0.2798)  loss_box_reg: 0.0923 (0.1493)  loss_objectness: 0.0021 (0.0092)  loss_rpn_box_reg: 0.0145 (0.0230)  time: 0.3991  data: 0.0166  max mem: 6375
# Epoch: [0]  [ 790/1226]  eta: 0:02:50  lr: 0.003956  loss: 0.2804 (0.4594)  loss_classifier: 0.1397 (0.2784)  loss_box_reg: 0.0923 (0.1486)  loss_objectness: 0.0032 (0.0092)  loss_rpn_box_reg: 0.0145 (0.0231)  time: 0.3936  data: 0.0158  max mem: 6375
# Epoch: [0]  [ 800/1226]  eta: 0:02:46  lr: 0.004006  loss: 0.2629 (0.4572)  loss_classifier: 0.1179 (0.2766)  loss_box_reg: 0.0824 (0.1479)  loss_objectness: 0.0026 (0.0093)  loss_rpn_box_reg: 0.0264 (0.0233)  time: 0.3845  data: 0.0159  max mem: 6375
# Epoch: [0]  [ 810/1226]  eta: 0:02:42  lr: 0.004056  loss: 0.2041 (0.4547)  loss_classifier: 0.0994 (0.2748)  loss_box_reg: 0.0824 (0.1473)  loss_objectness: 0.0025 (0.0092)  loss_rpn_box_reg: 0.0202 (0.0233)  time: 0.3822  data: 0.0153  max mem: 6375
# Epoch: [0]  [ 820/1226]  eta: 0:02:38  lr: 0.004106  loss: 0.2041 (0.4533)  loss_classifier: 0.1093 (0.2740)  loss_box_reg: 0.0801 (0.1467)  loss_objectness: 0.0048 (0.0094)  loss_rpn_box_reg: 0.0138 (0.0232)  time: 0.3848  data: 0.0150  max mem: 6375
# Epoch: [0]  [ 830/1226]  eta: 0:02:34  lr: 0.004156  loss: 0.1701 (0.4505)  loss_classifier: 0.0922 (0.2722)  loss_box_reg: 0.0472 (0.1458)  loss_objectness: 0.0061 (0.0094)  loss_rpn_box_reg: 0.0157 (0.0232)  time: 0.3868  data: 0.0147  max mem: 6375
# Epoch: [0]  [ 840/1226]  eta: 0:02:31  lr: 0.004206  loss: 0.2227 (0.4483)  loss_classifier: 0.1084 (0.2706)  loss_box_reg: 0.0632 (0.1449)  loss_objectness: 0.0071 (0.0096)  loss_rpn_box_reg: 0.0177 (0.0232)  time: 0.3850  data: 0.0154  max mem: 6375
# Epoch: [0]  [ 850/1226]  eta: 0:02:27  lr: 0.004256  loss: 0.2314 (0.4460)  loss_classifier: 0.1084 (0.2688)  loss_box_reg: 0.0641 (0.1443)  loss_objectness: 0.0078 (0.0096)  loss_rpn_box_reg: 0.0202 (0.0233)  time: 0.3924  data: 0.0149  max mem: 6375
# Epoch: [0]  [ 860/1226]  eta: 0:02:23  lr: 0.004306  loss: 0.2136 (0.4436)  loss_classifier: 0.0997 (0.2670)  loss_box_reg: 0.0805 (0.1437)  loss_objectness: 0.0058 (0.0096)  loss_rpn_box_reg: 0.0153 (0.0233)  time: 0.3981  data: 0.0137  max mem: 6375
# Epoch: [0]  [ 870/1226]  eta: 0:02:19  lr: 0.004356  loss: 0.2403 (0.4418)  loss_classifier: 0.1216 (0.2655)  loss_box_reg: 0.0855 (0.1433)  loss_objectness: 0.0091 (0.0096)  loss_rpn_box_reg: 0.0163 (0.0234)  time: 0.3957  data: 0.0158  max mem: 6375
# Epoch: [0]  [ 880/1226]  eta: 0:02:15  lr: 0.004406  loss: 0.2590 (0.4402)  loss_classifier: 0.1312 (0.2643)  loss_box_reg: 0.0855 (0.1428)  loss_objectness: 0.0091 (0.0097)  loss_rpn_box_reg: 0.0190 (0.0234)  time: 0.3836  data: 0.0159  max mem: 6375
# Epoch: [0]  [ 890/1226]  eta: 0:02:11  lr: 0.004456  loss: 0.2154 (0.4379)  loss_classifier: 0.1319 (0.2628)  loss_box_reg: 0.0660 (0.1420)  loss_objectness: 0.0062 (0.0097)  loss_rpn_box_reg: 0.0156 (0.0233)  time: 0.3779  data: 0.0141  max mem: 6375
# Epoch: [0]  [ 900/1226]  eta: 0:02:07  lr: 0.004505  loss: 0.2100 (0.4357)  loss_classifier: 0.1253 (0.2613)  loss_box_reg: 0.0660 (0.1414)  loss_objectness: 0.0055 (0.0097)  loss_rpn_box_reg: 0.0156 (0.0233)  time: 0.3951  data: 0.0142  max mem: 6375
# Epoch: [0]  [ 910/1226]  eta: 0:02:03  lr: 0.004555  loss: 0.1739 (0.4330)  loss_classifier: 0.0845 (0.2594)  loss_box_reg: 0.0521 (0.1406)  loss_objectness: 0.0059 (0.0097)  loss_rpn_box_reg: 0.0182 (0.0233)  time: 0.3990  data: 0.0150  max mem: 6375
# Epoch: [0]  [ 920/1226]  eta: 0:01:59  lr: 0.004605  loss: 0.2027 (0.4312)  loss_classifier: 0.1020 (0.2580)  loss_box_reg: 0.0656 (0.1403)  loss_objectness: 0.0058 (0.0096)  loss_rpn_box_reg: 0.0183 (0.0233)  time: 0.3849  data: 0.0157  max mem: 6375
# Epoch: [0]  [ 930/1226]  eta: 0:01:55  lr: 0.004655  loss: 0.2492 (0.4300)  loss_classifier: 0.1077 (0.2569)  loss_box_reg: 0.1017 (0.1399)  loss_objectness: 0.0042 (0.0096)  loss_rpn_box_reg: 0.0202 (0.0234)  time: 0.3830  data: 0.0157  max mem: 6375
# Epoch: [0]  [ 940/1226]  eta: 0:01:51  lr: 0.004705  loss: 0.2233 (0.4283)  loss_classifier: 0.1077 (0.2557)  loss_box_reg: 0.0762 (0.1395)  loss_objectness: 0.0075 (0.0097)  loss_rpn_box_reg: 0.0216 (0.0235)  time: 0.3934  data: 0.0149  max mem: 6375
# Epoch: [0]  [ 950/1226]  eta: 0:01:47  lr: 0.004755  loss: 0.2015 (0.4266)  loss_classifier: 0.1177 (0.2546)  loss_box_reg: 0.0690 (0.1390)  loss_objectness: 0.0052 (0.0096)  loss_rpn_box_reg: 0.0177 (0.0234)  time: 0.3911  data: 0.0155  max mem: 6375
# Epoch: [0]  [ 960/1226]  eta: 0:01:44  lr: 0.004805  loss: 0.1992 (0.4247)  loss_classifier: 0.1177 (0.2534)  loss_box_reg: 0.0589 (0.1382)  loss_objectness: 0.0049 (0.0096)  loss_rpn_box_reg: 0.0166 (0.0234)  time: 0.3886  data: 0.0163  max mem: 6375
# Epoch: [0]  [ 970/1226]  eta: 0:01:40  lr: 0.004855  loss: 0.2204 (0.4239)  loss_classifier: 0.1281 (0.2529)  loss_box_reg: 0.0691 (0.1380)  loss_objectness: 0.0063 (0.0097)  loss_rpn_box_reg: 0.0144 (0.0234)  time: 0.3881  data: 0.0165  max mem: 6375
# Epoch: [0]  [ 980/1226]  eta: 0:01:36  lr: 0.004905  loss: 0.2564 (0.4229)  loss_classifier: 0.1386 (0.2520)  loss_box_reg: 0.0744 (0.1376)  loss_objectness: 0.0096 (0.0098)  loss_rpn_box_reg: 0.0227 (0.0236)  time: 0.3695  data: 0.0156  max mem: 6375
# Epoch: [0]  [ 990/1226]  eta: 0:01:32  lr: 0.004955  loss: 0.1857 (0.4211)  loss_classifier: 0.1091 (0.2507)  loss_box_reg: 0.0480 (0.1371)  loss_objectness: 0.0106 (0.0098)  loss_rpn_box_reg: 0.0207 (0.0236)  time: 0.3615  data: 0.0159  max mem: 6375
# Epoch: [0]  [1000/1226]  eta: 0:01:28  lr: 0.005000  loss: 0.2821 (0.4201)  loss_classifier: 0.1488 (0.2498)  loss_box_reg: 0.0818 (0.1368)  loss_objectness: 0.0113 (0.0099)  loss_rpn_box_reg: 0.0173 (0.0236)  time: 0.3796  data: 0.0157  max mem: 6375
# Epoch: [0]  [1010/1226]  eta: 0:01:24  lr: 0.005000  loss: 0.2797 (0.4181)  loss_classifier: 0.1332 (0.2486)  loss_box_reg: 0.0818 (0.1362)  loss_objectness: 0.0067 (0.0098)  loss_rpn_box_reg: 0.0118 (0.0235)  time: 0.3755  data: 0.0145  max mem: 6375
# Epoch: [0]  [1020/1226]  eta: 0:01:20  lr: 0.005000  loss: 0.1951 (0.4162)  loss_classifier: 0.1054 (0.2473)  loss_box_reg: 0.0633 (0.1356)  loss_objectness: 0.0039 (0.0098)  loss_rpn_box_reg: 0.0138 (0.0235)  time: 0.3700  data: 0.0148  max mem: 6375
# Epoch: [0]  [1030/1226]  eta: 0:01:16  lr: 0.005000  loss: 0.2152 (0.4147)  loss_classifier: 0.1153 (0.2464)  loss_box_reg: 0.0583 (0.1350)  loss_objectness: 0.0059 (0.0099)  loss_rpn_box_reg: 0.0151 (0.0234)  time: 0.3829  data: 0.0150  max mem: 6375
# Epoch: [0]  [1040/1226]  eta: 0:01:12  lr: 0.005000  loss: 0.2577 (0.4139)  loss_classifier: 0.1295 (0.2458)  loss_box_reg: 0.0726 (0.1347)  loss_objectness: 0.0059 (0.0099)  loss_rpn_box_reg: 0.0137 (0.0235)  time: 0.3793  data: 0.0160  max mem: 6375
# Epoch: [0]  [1050/1226]  eta: 0:01:08  lr: 0.005000  loss: 0.2829 (0.4131)  loss_classifier: 0.1552 (0.2452)  loss_box_reg: 0.0880 (0.1344)  loss_objectness: 0.0062 (0.0099)  loss_rpn_box_reg: 0.0242 (0.0235)  time: 0.3779  data: 0.0155  max mem: 6375
# Epoch: [0]  [1060/1226]  eta: 0:01:04  lr: 0.005000  loss: 0.2494 (0.4116)  loss_classifier: 0.1034 (0.2442)  loss_box_reg: 0.0958 (0.1340)  loss_objectness: 0.0072 (0.0099)  loss_rpn_box_reg: 0.0210 (0.0236)  time: 0.3713  data: 0.0155  max mem: 6375
# Epoch: [0]  [1070/1226]  eta: 0:01:00  lr: 0.005000  loss: 0.2221 (0.4099)  loss_classifier: 0.0986 (0.2431)  loss_box_reg: 0.0592 (0.1334)  loss_objectness: 0.0056 (0.0099)  loss_rpn_box_reg: 0.0210 (0.0236)  time: 0.3693  data: 0.0154  max mem: 6375
# Epoch: [0]  [1080/1226]  eta: 0:00:56  lr: 0.005000  loss: 0.2221 (0.4085)  loss_classifier: 0.1189 (0.2420)  loss_box_reg: 0.0687 (0.1331)  loss_objectness: 0.0055 (0.0098)  loss_rpn_box_reg: 0.0134 (0.0236)  time: 0.3826  data: 0.0147  max mem: 6375
# Epoch: [0]  [1090/1226]  eta: 0:00:52  lr: 0.005000  loss: 0.2713 (0.4079)  loss_classifier: 0.1323 (0.2414)  loss_box_reg: 0.0872 (0.1329)  loss_objectness: 0.0068 (0.0100)  loss_rpn_box_reg: 0.0111 (0.0236)  time: 0.3955  data: 0.0150  max mem: 6375
# Epoch: [0]  [1100/1226]  eta: 0:00:49  lr: 0.005000  loss: 0.2641 (0.4064)  loss_classifier: 0.1403 (0.2405)  loss_box_reg: 0.0801 (0.1323)  loss_objectness: 0.0101 (0.0100)  loss_rpn_box_reg: 0.0145 (0.0235)  time: 0.4014  data: 0.0146  max mem: 6375
# Epoch: [0]  [1110/1226]  eta: 0:00:45  lr: 0.005000  loss: 0.2182 (0.4051)  loss_classifier: 0.1259 (0.2397)  loss_box_reg: 0.0547 (0.1318)  loss_objectness: 0.0125 (0.0101)  loss_rpn_box_reg: 0.0145 (0.0235)  time: 0.3945  data: 0.0140  max mem: 6375
# Epoch: [0]  [1120/1226]  eta: 0:00:41  lr: 0.005000  loss: 0.2182 (0.4035)  loss_classifier: 0.1207 (0.2385)  loss_box_reg: 0.0600 (0.1314)  loss_objectness: 0.0098 (0.0101)  loss_rpn_box_reg: 0.0143 (0.0235)  time: 0.3947  data: 0.0142  max mem: 6375
# Epoch: [0]  [1130/1226]  eta: 0:00:37  lr: 0.005000  loss: 0.1695 (0.4020)  loss_classifier: 0.0872 (0.2375)  loss_box_reg: 0.0504 (0.1309)  loss_objectness: 0.0048 (0.0101)  loss_rpn_box_reg: 0.0179 (0.0235)  time: 0.3952  data: 0.0147  max mem: 6375
# Epoch: [0]  [1140/1226]  eta: 0:00:33  lr: 0.005000  loss: 0.2380 (0.4015)  loss_classifier: 0.1134 (0.2371)  loss_box_reg: 0.0594 (0.1306)  loss_objectness: 0.0036 (0.0102)  loss_rpn_box_reg: 0.0242 (0.0236)  time: 0.3995  data: 0.0158  max mem: 6375
# Epoch: [0]  [1150/1226]  eta: 0:00:29  lr: 0.005000  loss: 0.3225 (0.4010)  loss_classifier: 0.1715 (0.2368)  loss_box_reg: 0.1107 (0.1305)  loss_objectness: 0.0093 (0.0102)  loss_rpn_box_reg: 0.0225 (0.0236)  time: 0.3907  data: 0.0151  max mem: 6375
# Epoch: [0]  [1160/1226]  eta: 0:00:25  lr: 0.005000  loss: 0.2189 (0.3990)  loss_classifier: 0.1137 (0.2355)  loss_box_reg: 0.0559 (0.1298)  loss_objectness: 0.0080 (0.0101)  loss_rpn_box_reg: 0.0175 (0.0236)  time: 0.3764  data: 0.0155  max mem: 6375
# Epoch: [0]  [1170/1226]  eta: 0:00:21  lr: 0.005000  loss: 0.1769 (0.3984)  loss_classifier: 0.0994 (0.2348)  loss_box_reg: 0.0522 (0.1298)  loss_objectness: 0.0070 (0.0102)  loss_rpn_box_reg: 0.0166 (0.0236)  time: 0.3760  data: 0.0150  max mem: 6375
# Epoch: [0]  [1180/1226]  eta: 0:00:17  lr: 0.005000  loss: 0.2523 (0.3971)  loss_classifier: 0.1391 (0.2339)  loss_box_reg: 0.0656 (0.1294)  loss_objectness: 0.0070 (0.0102)  loss_rpn_box_reg: 0.0179 (0.0236)  time: 0.3723  data: 0.0145  max mem: 6375
# Epoch: [0]  [1190/1226]  eta: 0:00:14  lr: 0.005000  loss: 0.2563 (0.3964)  loss_classifier: 0.1404 (0.2333)  loss_box_reg: 0.0888 (0.1292)  loss_objectness: 0.0066 (0.0102)  loss_rpn_box_reg: 0.0181 (0.0236)  time: 0.3704  data: 0.0139  max mem: 6375
# Epoch: [0]  [1200/1226]  eta: 0:00:10  lr: 0.005000  loss: 0.2181 (0.3946)  loss_classifier: 0.1131 (0.2323)  loss_box_reg: 0.0694 (0.1286)  loss_objectness: 0.0073 (0.0102)  loss_rpn_box_reg: 0.0169 (0.0235)  time: 0.3808  data: 0.0145  max mem: 6375
# Epoch: [0]  [1210/1226]  eta: 0:00:06  lr: 0.005000  loss: 0.1838 (0.3935)  loss_classifier: 0.1106 (0.2315)  loss_box_reg: 0.0616 (0.1283)  loss_objectness: 0.0084 (0.0102)  loss_rpn_box_reg: 0.0125 (0.0235)  time: 0.4030  data: 0.0163  max mem: 6375
# Epoch: [0]  [1220/1226]  eta: 0:00:02  lr: 0.005000  loss: 0.2688 (0.3932)  loss_classifier: 0.1571 (0.2314)  loss_box_reg: 0.0800 (0.1282)  loss_objectness: 0.0086 (0.0102)  loss_rpn_box_reg: 0.0159 (0.0234)  time: 0.3893  data: 0.0145  max mem: 6375
# Epoch: [0]  [1225/1226]  eta: 0:00:00  lr: 0.005000  loss: 0.2499 (0.3923)  loss_classifier: 0.1565 (0.2308)  loss_box_reg: 0.0678 (0.1279)  loss_objectness: 0.0084 (0.0102)  loss_rpn_box_reg: 0.0136 (0.0234)  time: 0.3910  data: 0.0143  max mem: 6375
# Epoch: [0] Total time: 0:07:57 (0.3894 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.0943 (0.0943)  evaluator_time: 0.0030 (0.0030)  time: 0.1043  data: 0.0050  max mem: 6375
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0692 (0.0730)  evaluator_time: 0.0020 (0.0027)  time: 0.0794  data: 0.0060  max mem: 6375
# Test: Total time: 0:00:04 (0.0827 s / it)
# Averaged stats: model_time: 0.0692 (0.0730)  evaluator_time: 0.0020 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.733
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.432
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.520
# Epoch: [1]  [   0/1226]  eta: 0:07:59  lr: 0.005000  loss: 0.1379 (0.1379)  loss_classifier: 0.0437 (0.0437)  loss_box_reg: 0.0172 (0.0172)  loss_objectness: 0.0093 (0.0093)  loss_rpn_box_reg: 0.0676 (0.0676)  time: 0.3910  data: 0.0120  max mem: 6375
# Epoch: [1]  [  10/1226]  eta: 0:07:26  lr: 0.005000  loss: 0.1600 (0.2317)  loss_classifier: 0.1029 (0.1245)  loss_box_reg: 0.0323 (0.0547)  loss_objectness: 0.0093 (0.0128)  loss_rpn_box_reg: 0.0345 (0.0397)  time: 0.3670  data: 0.0139  max mem: 6375
# Epoch: [1]  [  20/1226]  eta: 0:07:33  lr: 0.005000  loss: 0.1875 (0.2363)  loss_classifier: 0.1032 (0.1251)  loss_box_reg: 0.0597 (0.0674)  loss_objectness: 0.0094 (0.0129)  loss_rpn_box_reg: 0.0236 (0.0309)  time: 0.3756  data: 0.0147  max mem: 6375
# Epoch: [1]  [  30/1226]  eta: 0:07:37  lr: 0.005000  loss: 0.2331 (0.2444)  loss_classifier: 0.1078 (0.1297)  loss_box_reg: 0.0710 (0.0764)  loss_objectness: 0.0056 (0.0103)  loss_rpn_box_reg: 0.0181 (0.0281)  time: 0.3914  data: 0.0163  max mem: 6375
# Epoch: [1]  [  40/1226]  eta: 0:07:31  lr: 0.005000  loss: 0.2474 (0.2518)  loss_classifier: 0.1176 (0.1289)  loss_box_reg: 0.1091 (0.0856)  loss_objectness: 0.0061 (0.0105)  loss_rpn_box_reg: 0.0180 (0.0268)  time: 0.3849  data: 0.0171  max mem: 6375
# Epoch: [1]  [  50/1226]  eta: 0:07:29  lr: 0.005000  loss: 0.2474 (0.2549)  loss_classifier: 0.1186 (0.1306)  loss_box_reg: 0.1091 (0.0891)  loss_objectness: 0.0061 (0.0098)  loss_rpn_box_reg: 0.0174 (0.0254)  time: 0.3806  data: 0.0169  max mem: 6375
# Epoch: [1]  [  60/1226]  eta: 0:07:28  lr: 0.005000  loss: 0.2555 (0.2639)  loss_classifier: 0.1235 (0.1373)  loss_box_reg: 0.0974 (0.0908)  loss_objectness: 0.0045 (0.0091)  loss_rpn_box_reg: 0.0207 (0.0268)  time: 0.3925  data: 0.0179  max mem: 6375
# Epoch: [1]  [  70/1226]  eta: 0:07:33  lr: 0.005000  loss: 0.2467 (0.2566)  loss_classifier: 0.1235 (0.1339)  loss_box_reg: 0.0770 (0.0879)  loss_objectness: 0.0047 (0.0087)  loss_rpn_box_reg: 0.0204 (0.0261)  time: 0.4177  data: 0.0256  max mem: 6375
# Epoch: [1]  [  80/1226]  eta: 0:07:28  lr: 0.005000  loss: 0.2063 (0.2520)  loss_classifier: 0.1031 (0.1328)  loss_box_reg: 0.0537 (0.0847)  loss_objectness: 0.0031 (0.0083)  loss_rpn_box_reg: 0.0166 (0.0262)  time: 0.4111  data: 0.0241  max mem: 6375
# Epoch: [1]  [  90/1226]  eta: 0:07:23  lr: 0.005000  loss: 0.1837 (0.2470)  loss_classifier: 0.0908 (0.1302)  loss_box_reg: 0.0584 (0.0839)  loss_objectness: 0.0031 (0.0080)  loss_rpn_box_reg: 0.0129 (0.0249)  time: 0.3842  data: 0.0153  max mem: 6375
# Epoch: [1]  [ 100/1226]  eta: 0:07:20  lr: 0.005000  loss: 0.1842 (0.2502)  loss_classifier: 0.0950 (0.1323)  loss_box_reg: 0.0705 (0.0850)  loss_objectness: 0.0054 (0.0081)  loss_rpn_box_reg: 0.0129 (0.0248)  time: 0.3932  data: 0.0160  max mem: 6375
# Epoch: [1]  [ 110/1226]  eta: 0:07:14  lr: 0.005000  loss: 0.1721 (0.2456)  loss_classifier: 0.0950 (0.1306)  loss_box_reg: 0.0551 (0.0833)  loss_objectness: 0.0048 (0.0078)  loss_rpn_box_reg: 0.0133 (0.0238)  time: 0.3871  data: 0.0164  max mem: 6375
# Epoch: [1]  [ 120/1226]  eta: 0:07:09  lr: 0.005000  loss: 0.1631 (0.2447)  loss_classifier: 0.0999 (0.1295)  loss_box_reg: 0.0515 (0.0831)  loss_objectness: 0.0027 (0.0080)  loss_rpn_box_reg: 0.0152 (0.0242)  time: 0.3730  data: 0.0157  max mem: 6375
# Epoch: [1]  [ 130/1226]  eta: 0:07:05  lr: 0.005000  loss: 0.2392 (0.2474)  loss_classifier: 0.1354 (0.1315)  loss_box_reg: 0.0744 (0.0835)  loss_objectness: 0.0052 (0.0081)  loss_rpn_box_reg: 0.0180 (0.0244)  time: 0.3806  data: 0.0154  max mem: 6375
# Epoch: [1]  [ 140/1226]  eta: 0:07:03  lr: 0.005000  loss: 0.2283 (0.2445)  loss_classifier: 0.1135 (0.1298)  loss_box_reg: 0.0791 (0.0828)  loss_objectness: 0.0062 (0.0080)  loss_rpn_box_reg: 0.0168 (0.0240)  time: 0.4010  data: 0.0156  max mem: 6375
# Epoch: [1]  [ 150/1226]  eta: 0:06:58  lr: 0.005000  loss: 0.1989 (0.2436)  loss_classifier: 0.0881 (0.1281)  loss_box_reg: 0.0795 (0.0828)  loss_objectness: 0.0067 (0.0079)  loss_rpn_box_reg: 0.0176 (0.0248)  time: 0.3929  data: 0.0166  max mem: 6375
# Epoch: [1]  [ 160/1226]  eta: 0:06:54  lr: 0.005000  loss: 0.1989 (0.2417)  loss_classifier: 0.0853 (0.1269)  loss_box_reg: 0.0686 (0.0822)  loss_objectness: 0.0050 (0.0078)  loss_rpn_box_reg: 0.0211 (0.0248)  time: 0.3776  data: 0.0156  max mem: 6375
# Epoch: [1]  [ 170/1226]  eta: 0:06:50  lr: 0.005000  loss: 0.1901 (0.2451)  loss_classifier: 0.0836 (0.1283)  loss_box_reg: 0.0681 (0.0846)  loss_objectness: 0.0054 (0.0078)  loss_rpn_box_reg: 0.0154 (0.0243)  time: 0.3862  data: 0.0151  max mem: 6375
# Epoch: [1]  [ 180/1226]  eta: 0:06:45  lr: 0.005000  loss: 0.2356 (0.2471)  loss_classifier: 0.1322 (0.1298)  loss_box_reg: 0.0882 (0.0849)  loss_objectness: 0.0056 (0.0079)  loss_rpn_box_reg: 0.0155 (0.0245)  time: 0.3777  data: 0.0149  max mem: 6375
# Epoch: [1]  [ 190/1226]  eta: 0:06:41  lr: 0.005000  loss: 0.2463 (0.2493)  loss_classifier: 0.1417 (0.1313)  loss_box_reg: 0.0882 (0.0859)  loss_objectness: 0.0074 (0.0079)  loss_rpn_box_reg: 0.0166 (0.0242)  time: 0.3831  data: 0.0149  max mem: 6375
# Epoch: [1]  [ 200/1226]  eta: 0:06:37  lr: 0.005000  loss: 0.2305 (0.2505)  loss_classifier: 0.1521 (0.1323)  loss_box_reg: 0.0878 (0.0858)  loss_objectness: 0.0058 (0.0079)  loss_rpn_box_reg: 0.0166 (0.0245)  time: 0.3892  data: 0.0160  max mem: 6375
# Epoch: [1]  [ 210/1226]  eta: 0:06:34  lr: 0.005000  loss: 0.2308 (0.2531)  loss_classifier: 0.1338 (0.1338)  loss_box_reg: 0.0821 (0.0869)  loss_objectness: 0.0038 (0.0079)  loss_rpn_box_reg: 0.0161 (0.0246)  time: 0.3870  data: 0.0162  max mem: 6375
# Epoch: [1]  [ 220/1226]  eta: 0:06:30  lr: 0.005000  loss: 0.2814 (0.2550)  loss_classifier: 0.1308 (0.1349)  loss_box_reg: 0.0807 (0.0875)  loss_objectness: 0.0073 (0.0081)  loss_rpn_box_reg: 0.0161 (0.0245)  time: 0.3956  data: 0.0148  max mem: 6375
# Epoch: [1]  [ 230/1226]  eta: 0:06:26  lr: 0.005000  loss: 0.2634 (0.2565)  loss_classifier: 0.1555 (0.1360)  loss_box_reg: 0.0658 (0.0879)  loss_objectness: 0.0074 (0.0081)  loss_rpn_box_reg: 0.0201 (0.0244)  time: 0.3931  data: 0.0141  max mem: 6375
# Epoch: [1]  [ 240/1226]  eta: 0:06:23  lr: 0.005000  loss: 0.2041 (0.2554)  loss_classifier: 0.1066 (0.1360)  loss_box_reg: 0.0515 (0.0869)  loss_objectness: 0.0064 (0.0082)  loss_rpn_box_reg: 0.0178 (0.0242)  time: 0.3928  data: 0.0142  max mem: 6375
# Epoch: [1]  [ 250/1226]  eta: 0:06:19  lr: 0.005000  loss: 0.1900 (0.2562)  loss_classifier: 0.1066 (0.1370)  loss_box_reg: 0.0569 (0.0870)  loss_objectness: 0.0057 (0.0082)  loss_rpn_box_reg: 0.0161 (0.0241)  time: 0.3954  data: 0.0146  max mem: 6375
# Epoch: [1]  [ 260/1226]  eta: 0:06:17  lr: 0.005000  loss: 0.1862 (0.2561)  loss_classifier: 0.1276 (0.1372)  loss_box_reg: 0.0529 (0.0862)  loss_objectness: 0.0040 (0.0082)  loss_rpn_box_reg: 0.0161 (0.0244)  time: 0.4095  data: 0.0169  max mem: 6375
# Epoch: [1]  [ 270/1226]  eta: 0:06:13  lr: 0.005000  loss: 0.2459 (0.2590)  loss_classifier: 0.1392 (0.1391)  loss_box_reg: 0.0649 (0.0871)  loss_objectness: 0.0070 (0.0083)  loss_rpn_box_reg: 0.0239 (0.0245)  time: 0.4098  data: 0.0166  max mem: 6375
# Epoch: [1]  [ 280/1226]  eta: 0:06:09  lr: 0.005000  loss: 0.2213 (0.2581)  loss_classifier: 0.1360 (0.1388)  loss_box_reg: 0.0658 (0.0868)  loss_objectness: 0.0075 (0.0083)  loss_rpn_box_reg: 0.0158 (0.0242)  time: 0.3975  data: 0.0148  max mem: 6375
# Epoch: [1]  [ 290/1226]  eta: 0:06:06  lr: 0.005000  loss: 0.1910 (0.2576)  loss_classifier: 0.1272 (0.1387)  loss_box_reg: 0.0599 (0.0867)  loss_objectness: 0.0044 (0.0082)  loss_rpn_box_reg: 0.0146 (0.0240)  time: 0.4077  data: 0.0148  max mem: 6375
# Epoch: [1]  [ 300/1226]  eta: 0:06:02  lr: 0.005000  loss: 0.2071 (0.2572)  loss_classifier: 0.1206 (0.1385)  loss_box_reg: 0.0690 (0.0866)  loss_objectness: 0.0040 (0.0081)  loss_rpn_box_reg: 0.0136 (0.0240)  time: 0.3969  data: 0.0153  max mem: 6375
# Epoch: [1]  [ 310/1226]  eta: 0:05:58  lr: 0.005000  loss: 0.2034 (0.2544)  loss_classifier: 0.0984 (0.1369)  loss_box_reg: 0.0609 (0.0855)  loss_objectness: 0.0041 (0.0080)  loss_rpn_box_reg: 0.0125 (0.0240)  time: 0.3826  data: 0.0153  max mem: 6375
# Epoch: [1]  [ 320/1226]  eta: 0:05:55  lr: 0.005000  loss: 0.1442 (0.2522)  loss_classifier: 0.0596 (0.1354)  loss_box_reg: 0.0496 (0.0848)  loss_objectness: 0.0038 (0.0079)  loss_rpn_box_reg: 0.0154 (0.0241)  time: 0.4029  data: 0.0159  max mem: 6375
# Epoch: [1]  [ 330/1226]  eta: 0:05:51  lr: 0.005000  loss: 0.2339 (0.2546)  loss_classifier: 0.1061 (0.1368)  loss_box_reg: 0.0786 (0.0860)  loss_objectness: 0.0038 (0.0079)  loss_rpn_box_reg: 0.0154 (0.0239)  time: 0.4037  data: 0.0152  max mem: 6375
# Epoch: [1]  [ 340/1226]  eta: 0:05:46  lr: 0.005000  loss: 0.2794 (0.2545)  loss_classifier: 0.1509 (0.1369)  loss_box_reg: 0.0970 (0.0858)  loss_objectness: 0.0047 (0.0081)  loss_rpn_box_reg: 0.0146 (0.0237)  time: 0.3829  data: 0.0132  max mem: 6375
# Epoch: [1]  [ 350/1226]  eta: 0:05:42  lr: 0.005000  loss: 0.1964 (0.2554)  loss_classifier: 0.0968 (0.1370)  loss_box_reg: 0.0897 (0.0864)  loss_objectness: 0.0051 (0.0081)  loss_rpn_box_reg: 0.0161 (0.0238)  time: 0.3833  data: 0.0133  max mem: 6375
# Epoch: [1]  [ 360/1226]  eta: 0:05:39  lr: 0.005000  loss: 0.2364 (0.2571)  loss_classifier: 0.1072 (0.1378)  loss_box_reg: 0.1027 (0.0873)  loss_objectness: 0.0080 (0.0081)  loss_rpn_box_reg: 0.0139 (0.0239)  time: 0.4090  data: 0.0156  max mem: 6375
# Epoch: [1]  [ 370/1226]  eta: 0:05:35  lr: 0.005000  loss: 0.2520 (0.2568)  loss_classifier: 0.1278 (0.1375)  loss_box_reg: 0.1027 (0.0874)  loss_objectness: 0.0042 (0.0081)  loss_rpn_box_reg: 0.0153 (0.0239)  time: 0.4048  data: 0.0174  max mem: 6375
# Epoch: [1]  [ 380/1226]  eta: 0:05:31  lr: 0.005000  loss: 0.2711 (0.2569)  loss_classifier: 0.1164 (0.1373)  loss_box_reg: 0.0803 (0.0874)  loss_objectness: 0.0045 (0.0082)  loss_rpn_box_reg: 0.0176 (0.0240)  time: 0.3800  data: 0.0153  max mem: 6375
# Epoch: [1]  [ 390/1226]  eta: 0:05:27  lr: 0.005000  loss: 0.1737 (0.2548)  loss_classifier: 0.0919 (0.1360)  loss_box_reg: 0.0594 (0.0870)  loss_objectness: 0.0044 (0.0080)  loss_rpn_box_reg: 0.0174 (0.0238)  time: 0.3811  data: 0.0154  max mem: 6375
# Epoch: [1]  [ 400/1226]  eta: 0:05:23  lr: 0.005000  loss: 0.1573 (0.2542)  loss_classifier: 0.0765 (0.1358)  loss_box_reg: 0.0525 (0.0866)  loss_objectness: 0.0020 (0.0079)  loss_rpn_box_reg: 0.0163 (0.0238)  time: 0.3913  data: 0.0172  max mem: 6375
# Epoch: [1]  [ 410/1226]  eta: 0:05:19  lr: 0.005000  loss: 0.2005 (0.2537)  loss_classifier: 0.0984 (0.1356)  loss_box_reg: 0.0549 (0.0865)  loss_objectness: 0.0040 (0.0080)  loss_rpn_box_reg: 0.0121 (0.0237)  time: 0.4036  data: 0.0159  max mem: 6375
# Epoch: [1]  [ 420/1226]  eta: 0:05:16  lr: 0.005000  loss: 0.2311 (0.2539)  loss_classifier: 0.1091 (0.1356)  loss_box_reg: 0.0694 (0.0867)  loss_objectness: 0.0046 (0.0080)  loss_rpn_box_reg: 0.0121 (0.0236)  time: 0.3992  data: 0.0150  max mem: 6375
# Epoch: [1]  [ 430/1226]  eta: 0:05:11  lr: 0.005000  loss: 0.2394 (0.2540)  loss_classifier: 0.1091 (0.1355)  loss_box_reg: 0.0825 (0.0871)  loss_objectness: 0.0059 (0.0080)  loss_rpn_box_reg: 0.0172 (0.0234)  time: 0.3866  data: 0.0146  max mem: 6375
# Epoch: [1]  [ 440/1226]  eta: 0:05:08  lr: 0.005000  loss: 0.2175 (0.2526)  loss_classifier: 0.0886 (0.1347)  loss_box_reg: 0.0825 (0.0867)  loss_objectness: 0.0046 (0.0079)  loss_rpn_box_reg: 0.0121 (0.0232)  time: 0.3962  data: 0.0142  max mem: 6375
# Epoch: [1]  [ 450/1226]  eta: 0:05:04  lr: 0.005000  loss: 0.1881 (0.2521)  loss_classifier: 0.0853 (0.1341)  loss_box_reg: 0.0630 (0.0867)  loss_objectness: 0.0043 (0.0079)  loss_rpn_box_reg: 0.0128 (0.0234)  time: 0.4089  data: 0.0141  max mem: 6375
# Epoch: [1]  [ 460/1226]  eta: 0:05:00  lr: 0.005000  loss: 0.1551 (0.2506)  loss_classifier: 0.0769 (0.1334)  loss_box_reg: 0.0602 (0.0861)  loss_objectness: 0.0030 (0.0078)  loss_rpn_box_reg: 0.0182 (0.0233)  time: 0.3849  data: 0.0137  max mem: 6375
# Epoch: [1]  [ 470/1226]  eta: 0:04:56  lr: 0.005000  loss: 0.1532 (0.2502)  loss_classifier: 0.0661 (0.1330)  loss_box_reg: 0.0602 (0.0860)  loss_objectness: 0.0020 (0.0077)  loss_rpn_box_reg: 0.0182 (0.0235)  time: 0.3777  data: 0.0142  max mem: 6375
# Epoch: [1]  [ 480/1226]  eta: 0:04:52  lr: 0.005000  loss: 0.1854 (0.2492)  loss_classifier: 0.1118 (0.1329)  loss_box_reg: 0.0540 (0.0854)  loss_objectness: 0.0040 (0.0077)  loss_rpn_box_reg: 0.0150 (0.0232)  time: 0.3947  data: 0.0167  max mem: 6375
# Epoch: [1]  [ 490/1226]  eta: 0:04:48  lr: 0.005000  loss: 0.1924 (0.2496)  loss_classifier: 0.1430 (0.1330)  loss_box_reg: 0.0596 (0.0855)  loss_objectness: 0.0052 (0.0077)  loss_rpn_box_reg: 0.0198 (0.0235)  time: 0.3918  data: 0.0153  max mem: 6375
# Epoch: [1]  [ 500/1226]  eta: 0:04:44  lr: 0.005000  loss: 0.2181 (0.2491)  loss_classifier: 0.0967 (0.1327)  loss_box_reg: 0.0661 (0.0851)  loss_objectness: 0.0063 (0.0076)  loss_rpn_box_reg: 0.0246 (0.0236)  time: 0.3914  data: 0.0157  max mem: 6375
# Epoch: [1]  [ 510/1226]  eta: 0:04:40  lr: 0.005000  loss: 0.2236 (0.2486)  loss_classifier: 0.1057 (0.1324)  loss_box_reg: 0.0741 (0.0849)  loss_objectness: 0.0063 (0.0077)  loss_rpn_box_reg: 0.0196 (0.0236)  time: 0.3740  data: 0.0177  max mem: 6375
# Epoch: [1]  [ 520/1226]  eta: 0:04:36  lr: 0.005000  loss: 0.2343 (0.2488)  loss_classifier: 0.1178 (0.1330)  loss_box_reg: 0.0741 (0.0846)  loss_objectness: 0.0042 (0.0078)  loss_rpn_box_reg: 0.0163 (0.0235)  time: 0.3795  data: 0.0172  max mem: 6375
# Epoch: [1]  [ 530/1226]  eta: 0:04:32  lr: 0.005000  loss: 0.3005 (0.2509)  loss_classifier: 0.1621 (0.1344)  loss_box_reg: 0.0790 (0.0851)  loss_objectness: 0.0049 (0.0078)  loss_rpn_box_reg: 0.0195 (0.0236)  time: 0.3921  data: 0.0166  max mem: 6375
# Epoch: [1]  [ 540/1226]  eta: 0:04:28  lr: 0.005000  loss: 0.2295 (0.2507)  loss_classifier: 0.1306 (0.1345)  loss_box_reg: 0.0605 (0.0848)  loss_objectness: 0.0081 (0.0078)  loss_rpn_box_reg: 0.0216 (0.0236)  time: 0.3738  data: 0.0151  max mem: 6375
# Epoch: [1]  [ 550/1226]  eta: 0:04:24  lr: 0.005000  loss: 0.2117 (0.2516)  loss_classifier: 0.1285 (0.1349)  loss_box_reg: 0.0456 (0.0850)  loss_objectness: 0.0057 (0.0079)  loss_rpn_box_reg: 0.0210 (0.0238)  time: 0.3815  data: 0.0153  max mem: 6375
# Epoch: [1]  [ 560/1226]  eta: 0:04:20  lr: 0.005000  loss: 0.2032 (0.2514)  loss_classifier: 0.1185 (0.1348)  loss_box_reg: 0.0481 (0.0847)  loss_objectness: 0.0056 (0.0079)  loss_rpn_box_reg: 0.0226 (0.0240)  time: 0.4089  data: 0.0155  max mem: 6375
# Epoch: [1]  [ 570/1226]  eta: 0:04:16  lr: 0.005000  loss: 0.2489 (0.2519)  loss_classifier: 0.1318 (0.1350)  loss_box_reg: 0.0785 (0.0849)  loss_objectness: 0.0056 (0.0080)  loss_rpn_box_reg: 0.0242 (0.0240)  time: 0.3984  data: 0.0171  max mem: 6375
# Epoch: [1]  [ 580/1226]  eta: 0:04:12  lr: 0.005000  loss: 0.2484 (0.2510)  loss_classifier: 0.1225 (0.1344)  loss_box_reg: 0.0785 (0.0847)  loss_objectness: 0.0050 (0.0079)  loss_rpn_box_reg: 0.0210 (0.0240)  time: 0.3859  data: 0.0167  max mem: 6375
# Epoch: [1]  [ 590/1226]  eta: 0:04:08  lr: 0.005000  loss: 0.1565 (0.2498)  loss_classifier: 0.0795 (0.1337)  loss_box_reg: 0.0536 (0.0843)  loss_objectness: 0.0040 (0.0080)  loss_rpn_box_reg: 0.0155 (0.0239)  time: 0.3887  data: 0.0161  max mem: 6375
# ...
# Epoch: [9]  [ 670/1226]  eta: 0:03:35  lr: 0.000005  loss: 0.0709 (0.1079)  loss_classifier: 0.0357 (0.0521)  loss_box_reg: 0.0156 (0.0358)  loss_objectness: 0.0008 (0.0023)  loss_rpn_box_reg: 0.0091 (0.0177)  time: 0.3733  data: 0.0162  max mem: 6845
# Epoch: [9]  [ 680/1226]  eta: 0:03:31  lr: 0.000005  loss: 0.1069 (0.1081)  loss_classifier: 0.0409 (0.0521)  loss_box_reg: 0.0272 (0.0359)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0124 (0.0177)  time: 0.3860  data: 0.0144  max mem: 6845
# Epoch: [9]  [ 690/1226]  eta: 0:03:27  lr: 0.000005  loss: 0.1083 (0.1080)  loss_classifier: 0.0529 (0.0521)  loss_box_reg: 0.0347 (0.0358)  loss_objectness: 0.0014 (0.0024)  loss_rpn_box_reg: 0.0152 (0.0177)  time: 0.3943  data: 0.0141  max mem: 6845
# Epoch: [9]  [ 700/1226]  eta: 0:03:23  lr: 0.000005  loss: 0.0986 (0.1080)  loss_classifier: 0.0409 (0.0520)  loss_box_reg: 0.0240 (0.0358)  loss_objectness: 0.0011 (0.0024)  loss_rpn_box_reg: 0.0148 (0.0178)  time: 0.4010  data: 0.0146  max mem: 6845
# Epoch: [9]  [ 710/1226]  eta: 0:03:20  lr: 0.000005  loss: 0.0986 (0.1085)  loss_classifier: 0.0409 (0.0522)  loss_box_reg: 0.0342 (0.0361)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0215 (0.0179)  time: 0.4073  data: 0.0149  max mem: 6845
# Epoch: [9]  [ 720/1226]  eta: 0:03:16  lr: 0.000005  loss: 0.1047 (0.1083)  loss_classifier: 0.0431 (0.0521)  loss_box_reg: 0.0336 (0.0360)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0160 (0.0179)  time: 0.3878  data: 0.0148  max mem: 6845
# Epoch: [9]  [ 730/1226]  eta: 0:03:12  lr: 0.000005  loss: 0.1047 (0.1085)  loss_classifier: 0.0561 (0.0522)  loss_box_reg: 0.0316 (0.0361)  loss_objectness: 0.0017 (0.0024)  loss_rpn_box_reg: 0.0114 (0.0179)  time: 0.3768  data: 0.0151  max mem: 6845
# Epoch: [9]  [ 740/1226]  eta: 0:03:08  lr: 0.000005  loss: 0.0924 (0.1079)  loss_classifier: 0.0415 (0.0519)  loss_box_reg: 0.0231 (0.0358)  loss_objectness: 0.0017 (0.0024)  loss_rpn_box_reg: 0.0105 (0.0179)  time: 0.3771  data: 0.0156  max mem: 6845
# Epoch: [9]  [ 750/1226]  eta: 0:03:04  lr: 0.000005  loss: 0.0823 (0.1079)  loss_classifier: 0.0352 (0.0519)  loss_box_reg: 0.0206 (0.0358)  loss_objectness: 0.0009 (0.0024)  loss_rpn_box_reg: 0.0088 (0.0178)  time: 0.3816  data: 0.0160  max mem: 6845
# Epoch: [9]  [ 760/1226]  eta: 0:03:00  lr: 0.000005  loss: 0.0937 (0.1080)  loss_classifier: 0.0473 (0.0519)  loss_box_reg: 0.0318 (0.0359)  loss_objectness: 0.0009 (0.0024)  loss_rpn_box_reg: 0.0102 (0.0178)  time: 0.3894  data: 0.0174  max mem: 6845
# Epoch: [9]  [ 770/1226]  eta: 0:02:56  lr: 0.000005  loss: 0.0900 (0.1080)  loss_classifier: 0.0433 (0.0519)  loss_box_reg: 0.0263 (0.0359)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0099 (0.0178)  time: 0.3782  data: 0.0154  max mem: 6845
# Epoch: [9]  [ 780/1226]  eta: 0:02:52  lr: 0.000005  loss: 0.0750 (0.1076)  loss_classifier: 0.0387 (0.0517)  loss_box_reg: 0.0220 (0.0357)  loss_objectness: 0.0024 (0.0024)  loss_rpn_box_reg: 0.0088 (0.0178)  time: 0.3779  data: 0.0150  max mem: 6845
# Epoch: [9]  [ 790/1226]  eta: 0:02:48  lr: 0.000005  loss: 0.0886 (0.1079)  loss_classifier: 0.0390 (0.0519)  loss_box_reg: 0.0303 (0.0358)  loss_objectness: 0.0016 (0.0024)  loss_rpn_box_reg: 0.0126 (0.0178)  time: 0.3750  data: 0.0156  max mem: 6845
# Epoch: [9]  [ 800/1226]  eta: 0:02:44  lr: 0.000005  loss: 0.0928 (0.1079)  loss_classifier: 0.0437 (0.0517)  loss_box_reg: 0.0349 (0.0359)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0148 (0.0179)  time: 0.3755  data: 0.0157  max mem: 6845
# Epoch: [9]  [ 810/1226]  eta: 0:02:40  lr: 0.000005  loss: 0.1118 (0.1078)  loss_classifier: 0.0437 (0.0517)  loss_box_reg: 0.0349 (0.0359)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0121 (0.0178)  time: 0.3803  data: 0.0158  max mem: 6845
# Epoch: [9]  [ 820/1226]  eta: 0:02:37  lr: 0.000005  loss: 0.1021 (0.1076)  loss_classifier: 0.0527 (0.0516)  loss_box_reg: 0.0341 (0.0358)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0099 (0.0178)  time: 0.3833  data: 0.0154  max mem: 6845
# Epoch: [9]  [ 830/1226]  eta: 0:02:33  lr: 0.000005  loss: 0.0966 (0.1080)  loss_classifier: 0.0518 (0.0519)  loss_box_reg: 0.0297 (0.0359)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0124 (0.0178)  time: 0.4051  data: 0.0162  max mem: 6845
# Epoch: [9]  [ 840/1226]  eta: 0:02:29  lr: 0.000005  loss: 0.0799 (0.1079)  loss_classifier: 0.0433 (0.0519)  loss_box_reg: 0.0284 (0.0358)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0154 (0.0178)  time: 0.3934  data: 0.0159  max mem: 6845
# Epoch: [9]  [ 850/1226]  eta: 0:02:25  lr: 0.000005  loss: 0.0860 (0.1079)  loss_classifier: 0.0398 (0.0519)  loss_box_reg: 0.0245 (0.0358)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0143 (0.0178)  time: 0.3758  data: 0.0148  max mem: 6845
# Epoch: [9]  [ 860/1226]  eta: 0:02:21  lr: 0.000005  loss: 0.0885 (0.1077)  loss_classifier: 0.0413 (0.0518)  loss_box_reg: 0.0226 (0.0357)  loss_objectness: 0.0021 (0.0024)  loss_rpn_box_reg: 0.0113 (0.0178)  time: 0.4052  data: 0.0134  max mem: 6845
# Epoch: [9]  [ 870/1226]  eta: 0:02:17  lr: 0.000005  loss: 0.0776 (0.1074)  loss_classifier: 0.0373 (0.0517)  loss_box_reg: 0.0194 (0.0355)  loss_objectness: 0.0014 (0.0024)  loss_rpn_box_reg: 0.0106 (0.0178)  time: 0.4241  data: 0.0134  max mem: 6845
# Epoch: [9]  [ 880/1226]  eta: 0:02:14  lr: 0.000005  loss: 0.0776 (0.1076)  loss_classifier: 0.0410 (0.0519)  loss_box_reg: 0.0215 (0.0356)  loss_objectness: 0.0005 (0.0024)  loss_rpn_box_reg: 0.0106 (0.0177)  time: 0.4063  data: 0.0133  max mem: 6845
# Epoch: [9]  [ 890/1226]  eta: 0:02:10  lr: 0.000005  loss: 0.0809 (0.1076)  loss_classifier: 0.0500 (0.0519)  loss_box_reg: 0.0271 (0.0356)  loss_objectness: 0.0011 (0.0024)  loss_rpn_box_reg: 0.0104 (0.0177)  time: 0.3839  data: 0.0119  max mem: 6845
# Epoch: [9]  [ 900/1226]  eta: 0:02:06  lr: 0.000005  loss: 0.0985 (0.1078)  loss_classifier: 0.0418 (0.0519)  loss_box_reg: 0.0270 (0.0357)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0162 (0.0178)  time: 0.3786  data: 0.0130  max mem: 6845
# Epoch: [9]  [ 910/1226]  eta: 0:02:02  lr: 0.000005  loss: 0.1012 (0.1083)  loss_classifier: 0.0463 (0.0522)  loss_box_reg: 0.0290 (0.0359)  loss_objectness: 0.0017 (0.0024)  loss_rpn_box_reg: 0.0143 (0.0178)  time: 0.3882  data: 0.0151  max mem: 6845
# Epoch: [9]  [ 920/1226]  eta: 0:01:58  lr: 0.000005  loss: 0.1026 (0.1082)  loss_classifier: 0.0463 (0.0521)  loss_box_reg: 0.0274 (0.0359)  loss_objectness: 0.0014 (0.0024)  loss_rpn_box_reg: 0.0143 (0.0178)  time: 0.3927  data: 0.0151  max mem: 6845
# Epoch: [9]  [ 930/1226]  eta: 0:01:54  lr: 0.000005  loss: 0.1079 (0.1084)  loss_classifier: 0.0519 (0.0522)  loss_box_reg: 0.0383 (0.0360)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0151 (0.0178)  time: 0.4047  data: 0.0150  max mem: 6845
# Epoch: [9]  [ 940/1226]  eta: 0:01:50  lr: 0.000005  loss: 0.0935 (0.1083)  loss_classifier: 0.0413 (0.0521)  loss_box_reg: 0.0336 (0.0359)  loss_objectness: 0.0015 (0.0024)  loss_rpn_box_reg: 0.0118 (0.0178)  time: 0.3945  data: 0.0147  max mem: 6845
# Epoch: [9]  [ 950/1226]  eta: 0:01:47  lr: 0.000005  loss: 0.0883 (0.1083)  loss_classifier: 0.0392 (0.0521)  loss_box_reg: 0.0276 (0.0360)  loss_objectness: 0.0014 (0.0024)  loss_rpn_box_reg: 0.0123 (0.0178)  time: 0.3865  data: 0.0157  max mem: 6845
# Epoch: [9]  [ 960/1226]  eta: 0:01:43  lr: 0.000005  loss: 0.1253 (0.1085)  loss_classifier: 0.0480 (0.0522)  loss_box_reg: 0.0319 (0.0360)  loss_objectness: 0.0014 (0.0024)  loss_rpn_box_reg: 0.0127 (0.0179)  time: 0.4036  data: 0.0163  max mem: 6845
# Epoch: [9]  [ 970/1226]  eta: 0:01:39  lr: 0.000005  loss: 0.0970 (0.1083)  loss_classifier: 0.0541 (0.0521)  loss_box_reg: 0.0249 (0.0360)  loss_objectness: 0.0009 (0.0024)  loss_rpn_box_reg: 0.0168 (0.0178)  time: 0.4038  data: 0.0158  max mem: 6845
# Epoch: [9]  [ 980/1226]  eta: 0:01:35  lr: 0.000005  loss: 0.0959 (0.1082)  loss_classifier: 0.0449 (0.0521)  loss_box_reg: 0.0281 (0.0359)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0151 (0.0179)  time: 0.3942  data: 0.0165  max mem: 6845
# Epoch: [9]  [ 990/1226]  eta: 0:01:31  lr: 0.000005  loss: 0.0968 (0.1082)  loss_classifier: 0.0414 (0.0520)  loss_box_reg: 0.0281 (0.0359)  loss_objectness: 0.0014 (0.0024)  loss_rpn_box_reg: 0.0133 (0.0179)  time: 0.4054  data: 0.0151  max mem: 6845
# Epoch: [9]  [1000/1226]  eta: 0:01:27  lr: 0.000005  loss: 0.0946 (0.1083)  loss_classifier: 0.0406 (0.0521)  loss_box_reg: 0.0246 (0.0359)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0117 (0.0179)  time: 0.3931  data: 0.0133  max mem: 6845
# Epoch: [9]  [1010/1226]  eta: 0:01:23  lr: 0.000005  loss: 0.0800 (0.1082)  loss_classifier: 0.0406 (0.0520)  loss_box_reg: 0.0245 (0.0359)  loss_objectness: 0.0009 (0.0024)  loss_rpn_box_reg: 0.0104 (0.0179)  time: 0.3749  data: 0.0134  max mem: 6845
# Epoch: [9]  [1020/1226]  eta: 0:01:19  lr: 0.000005  loss: 0.0855 (0.1080)  loss_classifier: 0.0450 (0.0520)  loss_box_reg: 0.0331 (0.0359)  loss_objectness: 0.0008 (0.0024)  loss_rpn_box_reg: 0.0104 (0.0178)  time: 0.3800  data: 0.0137  max mem: 6845
# Epoch: [9]  [1030/1226]  eta: 0:01:16  lr: 0.000005  loss: 0.0995 (0.1083)  loss_classifier: 0.0465 (0.0521)  loss_box_reg: 0.0333 (0.0360)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0156 (0.0179)  time: 0.3800  data: 0.0138  max mem: 6845
# Epoch: [9]  [1040/1226]  eta: 0:01:12  lr: 0.000005  loss: 0.0843 (0.1080)  loss_classifier: 0.0364 (0.0520)  loss_box_reg: 0.0208 (0.0358)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0162 (0.0178)  time: 0.3956  data: 0.0140  max mem: 6845
# Epoch: [9]  [1050/1226]  eta: 0:01:08  lr: 0.000005  loss: 0.0902 (0.1081)  loss_classifier: 0.0413 (0.0520)  loss_box_reg: 0.0282 (0.0359)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0103 (0.0178)  time: 0.3999  data: 0.0145  max mem: 6845
# Epoch: [9]  [1060/1226]  eta: 0:01:04  lr: 0.000005  loss: 0.1001 (0.1082)  loss_classifier: 0.0492 (0.0521)  loss_box_reg: 0.0365 (0.0359)  loss_objectness: 0.0015 (0.0024)  loss_rpn_box_reg: 0.0126 (0.0178)  time: 0.3838  data: 0.0160  max mem: 6845
# Epoch: [9]  [1070/1226]  eta: 0:01:00  lr: 0.000005  loss: 0.0970 (0.1083)  loss_classifier: 0.0392 (0.0522)  loss_box_reg: 0.0285 (0.0360)  loss_objectness: 0.0015 (0.0024)  loss_rpn_box_reg: 0.0142 (0.0178)  time: 0.3886  data: 0.0162  max mem: 6845
# Epoch: [9]  [1080/1226]  eta: 0:00:56  lr: 0.000005  loss: 0.0914 (0.1080)  loss_classifier: 0.0385 (0.0521)  loss_box_reg: 0.0285 (0.0358)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0123 (0.0177)  time: 0.3931  data: 0.0155  max mem: 6845
# Epoch: [9]  [1090/1226]  eta: 0:00:52  lr: 0.000005  loss: 0.0976 (0.1081)  loss_classifier: 0.0416 (0.0521)  loss_box_reg: 0.0292 (0.0359)  loss_objectness: 0.0007 (0.0024)  loss_rpn_box_reg: 0.0109 (0.0177)  time: 0.3892  data: 0.0151  max mem: 6845
# Epoch: [9]  [1100/1226]  eta: 0:00:48  lr: 0.000005  loss: 0.0992 (0.1080)  loss_classifier: 0.0436 (0.0521)  loss_box_reg: 0.0283 (0.0358)  loss_objectness: 0.0011 (0.0024)  loss_rpn_box_reg: 0.0110 (0.0177)  time: 0.3859  data: 0.0150  max mem: 6845
# Epoch: [9]  [1110/1226]  eta: 0:00:45  lr: 0.000005  loss: 0.0949 (0.1079)  loss_classifier: 0.0460 (0.0521)  loss_box_reg: 0.0277 (0.0358)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0094 (0.0176)  time: 0.3867  data: 0.0144  max mem: 6845
# Epoch: [9]  [1120/1226]  eta: 0:00:41  lr: 0.000005  loss: 0.0949 (0.1079)  loss_classifier: 0.0460 (0.0521)  loss_box_reg: 0.0271 (0.0358)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0120 (0.0176)  time: 0.3946  data: 0.0145  max mem: 6845
# Epoch: [9]  [1130/1226]  eta: 0:00:37  lr: 0.000005  loss: 0.0940 (0.1079)  loss_classifier: 0.0382 (0.0521)  loss_box_reg: 0.0261 (0.0358)  loss_objectness: 0.0027 (0.0024)  loss_rpn_box_reg: 0.0124 (0.0176)  time: 0.3891  data: 0.0145  max mem: 6845
# Epoch: [9]  [1140/1226]  eta: 0:00:33  lr: 0.000005  loss: 0.0814 (0.1076)  loss_classifier: 0.0382 (0.0520)  loss_box_reg: 0.0221 (0.0357)  loss_objectness: 0.0028 (0.0024)  loss_rpn_box_reg: 0.0102 (0.0176)  time: 0.3943  data: 0.0144  max mem: 6845
# Epoch: [9]  [1150/1226]  eta: 0:00:29  lr: 0.000005  loss: 0.0887 (0.1078)  loss_classifier: 0.0478 (0.0521)  loss_box_reg: 0.0277 (0.0357)  loss_objectness: 0.0014 (0.0024)  loss_rpn_box_reg: 0.0103 (0.0176)  time: 0.4069  data: 0.0151  max mem: 6845
# Epoch: [9]  [1160/1226]  eta: 0:00:25  lr: 0.000005  loss: 0.0868 (0.1076)  loss_classifier: 0.0397 (0.0520)  loss_box_reg: 0.0343 (0.0357)  loss_objectness: 0.0011 (0.0024)  loss_rpn_box_reg: 0.0149 (0.0176)  time: 0.3917  data: 0.0157  max mem: 6845
# Epoch: [9]  [1170/1226]  eta: 0:00:21  lr: 0.000005  loss: 0.0761 (0.1075)  loss_classifier: 0.0326 (0.0519)  loss_box_reg: 0.0223 (0.0356)  loss_objectness: 0.0018 (0.0024)  loss_rpn_box_reg: 0.0108 (0.0176)  time: 0.3823  data: 0.0159  max mem: 6845
# Epoch: [9]  [1180/1226]  eta: 0:00:17  lr: 0.000005  loss: 0.1058 (0.1079)  loss_classifier: 0.0369 (0.0521)  loss_box_reg: 0.0249 (0.0358)  loss_objectness: 0.0019 (0.0024)  loss_rpn_box_reg: 0.0123 (0.0176)  time: 0.3892  data: 0.0158  max mem: 6845
# Epoch: [9]  [1190/1226]  eta: 0:00:13  lr: 0.000005  loss: 0.1468 (0.1081)  loss_classifier: 0.0804 (0.0523)  loss_box_reg: 0.0369 (0.0359)  loss_objectness: 0.0019 (0.0024)  loss_rpn_box_reg: 0.0129 (0.0176)  time: 0.3904  data: 0.0161  max mem: 6845
# Epoch: [9]  [1200/1226]  eta: 0:00:10  lr: 0.000005  loss: 0.0843 (0.1081)  loss_classifier: 0.0462 (0.0522)  loss_box_reg: 0.0332 (0.0359)  loss_objectness: 0.0013 (0.0024)  loss_rpn_box_reg: 0.0106 (0.0176)  time: 0.3942  data: 0.0168  max mem: 6845
# Epoch: [9]  [1210/1226]  eta: 0:00:06  lr: 0.000005  loss: 0.0843 (0.1081)  loss_classifier: 0.0462 (0.0523)  loss_box_reg: 0.0332 (0.0359)  loss_objectness: 0.0007 (0.0024)  loss_rpn_box_reg: 0.0086 (0.0176)  time: 0.3770  data: 0.0160  max mem: 6845
# Epoch: [9]  [1220/1226]  eta: 0:00:02  lr: 0.000005  loss: 0.0954 (0.1080)  loss_classifier: 0.0394 (0.0522)  loss_box_reg: 0.0283 (0.0358)  loss_objectness: 0.0007 (0.0024)  loss_rpn_box_reg: 0.0134 (0.0176)  time: 0.3766  data: 0.0137  max mem: 6845
# Epoch: [9]  [1225/1226]  eta: 0:00:00  lr: 0.000005  loss: 0.0848 (0.1078)  loss_classifier: 0.0387 (0.0521)  loss_box_reg: 0.0256 (0.0358)  loss_objectness: 0.0007 (0.0024)  loss_rpn_box_reg: 0.0100 (0.0176)  time: 0.3770  data: 0.0132  max mem: 6845
# Epoch: [9] Total time: 0:07:56 (0.3885 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:04  model_time: 0.0782 (0.0782)  evaluator_time: 0.0020 (0.0020)  time: 0.0863  data: 0.0050  max mem: 6845
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0702 (0.0725)  evaluator_time: 0.0020 (0.0020)  time: 0.0787  data: 0.0059  max mem: 6845
# Test: Total time: 0:00:04 (0.0813 s / it)
# Averaged stats: model_time: 0.0702 (0.0725)  evaluator_time: 0.0020 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.580
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.662
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.580
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.618
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.672
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.702
# model saved.

# %%
def bb_hw(a): return np.array([a[0],a[1],a[2]-a[0]+1,a[3]-a[1]+1])

def show_img(im, figsize=None, ax=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    return ax

def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(
        linewidth=lw, foreground='black'), patheffects.Normal()])

def draw_rect(ax, b):    
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor='white', lw=2))    
    draw_outline(patch, 4)

def draw_text(ax, xy, txt, sz=14):
    text = ax.text(*xy, txt,
        verticalalignment='top', color='white', fontsize=sz, weight='bold')
    draw_outline(text, 1)

# %%
COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# %%
PATH = Path('data/pascal')   
#jsonname = 'pascal_train2007.json' 
jsonname = 'pascal_val2007.json' 
trn_j = json.load( (PATH/jsonname).open() )
cats =  {o['id']:o['name'] for o in trn_j['categories']}

# %%
test_idx = 18

modelsaved = get_model_instance_segmentation(num_classes, True)

#SAVED_PATH = './k_model_2019.06.25.nn.pt'
#SAVED_PATH = './cocopretrained_withepoch3_2019.06.26.pt'

modelsaved.load_state_dict( torch.load(SAVED_PATH))

modelsaved.eval()
modelsaved.to(device)
img, _ = dataset_test[test_idx]
# put the model in evaluation mode
modelsaved.eval()
with torch.no_grad():
    prediction = modelsaved([img.to(device)])
    
PATH = Path('data/pascal')   
#jsonname = 'pascal_train2007.json' 
jsonname = 'pascal_val2007.json' 
trn_j = json.load( (PATH/jsonname).open() )
cats =  {o['id']:o['name'] for o in trn_j['categories']}
    
    
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.patheffects as patheffects


#print(prediction[0]) # dict_keys(['boxes', 'labels', 'scores', 'masks'])
result = prediction[0]

#print(type(img))
toimg = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
ax = show_img(toimg, figsize=(6, 6)) 
threshold = 0.9
for box, score, label in zip(result['boxes'], result['scores'], result['labels']):    
    score = score.item()        
    if score <= threshold :
        break
    box = box.detach().cpu().clone().numpy()
    b = bb_hw(box)
    draw_rect(ax, b)
    print("label.item :", label.item())
    #resultscore = "{}, {:1.3f}".format( COCO_INSTANCE_CATEGORY_NAMES[label.item()], score )
    resultscore = "{}, {:1.3f}".format( cats[label.item()], score )
    
    
    draw_text(ax, b[:2], resultscore )
        
#plt.show()
# Out:
# label.item : 15
